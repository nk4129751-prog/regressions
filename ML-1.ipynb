# %%
import numpy as np 

x = np.array([700 ,800 ,900 ])
y = np.array([700000 ,800000 ,900000])
# Main formula --> y = mx+b 
#    m = mean(xy) - mean(x)*mean(Y) /mean(x**2)-(mean(X))2         b = mean(y)-mean*mean(x)
# Solution:
multiplication = x*y
print("multiplication:" , multiplication)
meanofxy = np.mean(multiplication)
print("mean of x and y : " , meanofxy)
meanofx = np.mean(x)
print("mean of x : " , meanofx)
meanofy = np.mean(y)
print ("mean of y : " , meanofy)
newvalofmeans = meanofx * meanofy
print("new values of means of x and y : " , newvalofmeans)
newvalofnumerator = meanofxy - newvalofmeans
print("new value of numerator : " , newvalofnumerator)
meanofxsquare = np.mean(x**2)
print("mean of x square : " , meanofxsquare)
squareofxmean = meanofx**2
print("square of x mean : " ,squareofxmean)
newvalofdenominator = meanofxsquare - squareofxmean
print("new value of denominator : " , newvalofdenominator)
m = newvalofnumerator / newvalofdenominator
print("slope : " , m)

intercept = meanofy - m*meanofx
print("intercept : " , intercept)

predictedvalue = m*1200 + intercept
print("predictedvalue : " ,predictedvalue)
# Out:
# multiplication: [490000000 640000000 810000000]
# mean of x and y :  646666666.6666666
# mean of x :  800.0
# mean of y :  800000.0
# new values of means of x and y :  640000000.0
# new value of numerator :  6666666.666666627
# mean of x square :  646666.6666666666
# square of x mean :  640000.0
# new value of denominator :  6666.666666666628
# slope :  999.9999999999999
# intercept :  1.1641532182693481e-10
# predictedvalue :  1200000.0
